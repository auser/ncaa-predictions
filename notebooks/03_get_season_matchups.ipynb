# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from pathlib import Path

from mbp.webscraping import activate_web_driver, get_team_page
from mbp.data import download_team_data, get_team_games_for_year
from mbp.paths import SEASONS_DIR, RAW_DATA_DIR

# %%
driver = activate_web_driver("firefox", True)

# Read team names
df = pd.read_csv(f"{RAW_DATA_DIR}/mbb_team_names_to_number.csv", index_col=0)

# %%
team_name = "Arizona"
raw_year = 2022

# %%
from selenium.webdriver.common.by import By

games_df = get_team_games_for_year(driver, df, team_name, raw_year)
games_df.head()
# get_team_page(driver, df, team_name, raw_year)

# tables = driver.find_elements(By.CSS_SELECTOR, "#contentarea table>tbody")
# for table in tables:
#     try:
#         legend = table.find_element(By.CSS_SELECTOR, "fieldset>legend")
#         if legend.text == "Schedule/Results":
#             schedule_result_element = table
#     except:
#         pass
# listing = schedule_result_element.find_elements(
#         By.CSS_SELECTOR, "fieldset table > tbody tr"
#     )
# print(listing[0].text)
# Out:
# parts: ['11/11/2022'] (1)
# parts: ['11/17/2022'] (1)
# parts: ['11/21/2022'] (1)
# parts: ['Cincinnati\n', 'Lahaina, HI (2022-23 MBB Maui Invitational)']
# parts: ['11/22/2022'] (1)
# parts: ['San Diego St.\n', 'Lahaina, HI (2022-23 MBB Maui Invitational)']
# parts: ['11/23/2022'] (1)
# parts: ['Creighton\n', 'Lahaina, HI (2022-23 MBB Maui Invitational)']
# parts: ['12/01/2022'] (1)
# parts: ['', ' Utah']
# parts: ['12/04/2022'] (1)
# parts: ['12/10/2022'] (1)
# parts: ['Indiana\n', 'Las Vegas, NV (2022-23 MBB Las Vegas Clash)']
# parts: ['12/13/2022'] (1)
# parts: ['12/17/2022'] (1)
# parts: ['12/20/2022'] (1)
# parts: ['12/22/2022'] (1)
# parts: ['12/31/2022'] (1)
# parts: ['', ' Arizona St.']
# parts: ['01/05/2023'] (1)
# parts: ['01/07/2023'] (1)
# parts: ['01/12/2023'] (1)
# parts: ['', ' Oregon St.']
# parts: ['01/14/2023'] (1)
# parts: ['', ' Oregon']
# parts: ['01/19/2023'] (1)
# parts: ['01/21/2023'] (1)
# parts: ['01/26/2023'] (1)
# parts: ['', ' Washington St.']
# parts: ['01/28/2023'] (1)
# parts: ['', ' Washington']
# parts: ['02/02/2023'] (1)
# parts: ['02/04/2023'] (1)
# parts: ['02/09/2023'] (1)
# parts: ['', ' California']
# parts: ['02/11/2023'] (1)
# parts: ['', ' Stanford']
# parts: ['02/16/2023'] (1)
# parts: ['02/18/2023'] (1)
# parts: ['02/25/2023'] (1)
# parts: ['03/02/2023'] (1)
# parts: ['', ' Southern California']
# parts: ['03/04/2023'] (1)
# parts: ['', ' UCLA']
# parts: ['03/09/2023'] (1)
# parts: ['#10 Stanford\n', 'Las Vegas, NV (2023 MBB Pac-12 Championship)']
# parts: ['03/10/2023'] (1)
# parts: ['#6 Arizona St.\n', 'Las Vegas, NV (2023 MBB Pac-12 Championship)']
# parts: ['03/11/2023'] (1)
# parts: ['#1 UCLA\n', 'Las Vegas, NV (2023 MBB Pac-12 Championship)']
# 3   11/22/2022  San Diego St.   W 87-70      2,400 2022-11-22   0.0
# 4   11/23/2022      Creighton   W 81-79      2,400 2022-11-23   0.0

# %%
# Download Arizona data
download_team_data(team_name, raw_year, True)
# Out:
# Downloading Arizona team games
# Downloading Arizona team roster
# Downloading Arizona team stats

# %%
# Get their games for the year
year_dir = Path(SEASONS_DIR / str(raw_year))
team_dir = year_dir / team_name
games_df = pd.read_csv(team_dir / "games.csv")

for opp in games_df['opponent']:
    opponent_games = year_dir / opp / "games.csv"
    if not opponent_games.exists():
        print(opp)
        download_team_data(opp, raw_year)
# Out:
# Utah Tech
# Downloading Utah Tech team games
# Downloading Utah Tech team roster
# Downloading Utah Tech team stats
# Cincinnati
# Downloading Cincinnati team games
# Downloading Cincinnati team roster
# Downloading Cincinnati team stats
# San Diego St.
# Downloading San Diego St. team games
# Downloading San Diego St. team roster
# Downloading San Diego St. team stats

# %%
# Get games for the year
games_df = pd.read_csv(f"{SEASONS_DIR}/{raw_year}/{team_name}_games.csv")
stats_df = download_raw_team_stats_for_year("Morgan St.", 2022)
stats_df
# for opponent in games_df['opponent']:
    # stats_df = get_team_stats(driver, df, team_name, raw_year)
# Out:
#    Jersey             Player  Yr Pos    Ht  GP  GS       MP   G  FGM  ... AST  \
# 0       2      Burke, Isaiah  Sr   G   6-1  31  31  1069:55  31  200  ...  86
# 1       4  Copeland, Daiquan  Jr   G   6-6  12   7   211:08  12   20  ...  23
# 2       5     Djonkam, Lewis  Sr   F   6-9  31  29   659:49  31  108  ...  35
# 3      14     Fagbenle, Toto  Sr   F   6-9  16   6   214:00  16   16  ...  12
# 4       0      Hobbs, Kamron  So   G  5-10  31  16   874:11  31   93  ...  83
# 5      31         Horner, Ty  Sr   F  6-10  26  11   309:01  26   28  ...  18
# 6       3        Lawson, Rob  Fr   G   6-0  29   1   560:48  29   54  ...  51
# 7      23  McCullough, David  Sr   G   6-6  19  12   350:40  19   35  ...  16
# 8      11      Miller, Malik  Sr   G   6-4  19  19   614:25  19  123  ...  74
# 9      21    Nnamene, Collin  Sr   F   6-9  30   3   375:59  30   22  ...  14
# 10     10       Thomas, Will  Jr   G   6-5  29   8   614:56  29  105  ...  37
# 11      1     Turner, Khalil  Jr   F   6-8  13  12   314:42  13   47  ...  25
# 12     22     Wiggins, Kevon  Jr   G   6-3  17   0   105:25  17   12  ...   5
#
#     TO STL BLK Fouls Dbl Dbl Trpl Dbl DQ Tech Fouls Effective FG Pct.
# 0   86  46   9    61                              1                 8
# 1   35  10   1    30                   1                            2
# 2   38  30  15   102                   9          1                10
# 3   14  17  10    35                              1                 2
# 4   59  44   3    60                              2                 8
# 5   10  10  10    58                   4                            7
# 6   43  27   1    53                   1                            8
# 7   30  18  14    36                   1                            4
# 8   65  39  13    52      10        1  2                            4
# 9   37  11  42    69                   2                            9
# 10  38  20   7    45       1                                        6
# 11  22  28  13    41       1           2          1                 2
# 12   9   3         5                                                2
#
# [13 rows x 34 columns]
